# %% [markdown]
# # BrainGraph 86-node set — minimal EDA
#
# This notebook:
# - Loads `.graphml` brain connectomes (86-node set) with **NetworkX**.
# - Inspects node/edge attributes.
# - Summarizes per-graph stats across many files.
# - Plots simple distributions.
#
# > Update `DATA_DIR` to your folder (defaults to `data/HCP/86_nodes`).

# %%
from pathlib import Path
import networkx as nx
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import torch
from torch_geometric.data import Data

# %%
DATA_DIR = Path("data/HCP/86_nodes")

assert DATA_DIR.exists(), f"DATA_DIR does not exist: {DATA_DIR}"
files = sorted(DATA_DIR.glob("*.graphml"))
print(f"Found {len(files)} .graphml files in {DATA_DIR}")
print("First 5 files:")
for f in files[:5]:
    print("  ", f.name)
# Out:
# Found 1064 .graphml files in data/HCP/86_nodes
# First 5 files:
#    100206_repeated10_scale33.graphml
#    100307_repeated10_scale33.graphml
#    100408_repeated10_scale33.graphml
#    100610_repeated10_scale33.graphml
#    101006_repeated10_scale33.graphml

# %%
PHENO_PATH = Path("data/HCP/HCP_phenotypes.csv")

assert PHENO_PATH.exists(), f"PHENO_PATH does not exist: {PHENO_PATH}"
pheno = pd.read_csv(PHENO_PATH)

print("Age_in_Yrs" in pheno.columns)
# Out:
# True

# %%
pheno.head()
# Out:
#    Subject Release Acquisition Gender    Age  Age_in_Yrs  HasGT ZygositySR  \
# 0   100004    S900         Q06      M  22-25          24   True    NotTwin
# 1   100206    S900         Q11      M  26-30          27   True    NotTwin
# 2   100307      Q1         Q01      F  26-30          27   True      NotMZ
# 3   100408      Q3         Q03      M  31-35          33   True         MZ
# 4   100610    S900         Q08      M  26-30          27   True      NotMZ
#
#   ZygosityGT    Family_ID  ...  MOV2_TRACKFRAC  MOV2_TRFRAC  MOV3_TRACKFRAC  \
# 0             52259_82122  ...             NaN          NaN             NaN
# 1             56037_85858  ...             NaN          NaN             NaN
# 2         MZ  51488_81352  ...             NaN          NaN             NaN
# 3         MZ  51730_81594  ...             NaN          NaN             NaN
# 4         DZ  52813_82634  ...             NaN          NaN             NaN
#
#   MOV3_TRFRAC MOV4_TRACKFRAC  MOV4_TRFRAC  MOV_EYETRACK_COMPL  \
# 0         NaN            NaN          NaN                 NaN
# 1         NaN            NaN          NaN                 NaN
# 2         NaN            NaN          NaN                 NaN
# 3         NaN            NaN          NaN                 NaN
# 4         NaN            NaN          NaN                 NaN
#
#    REST_TRACKFRAC_MIN  REST_TRFRAC_MIN  REST_EYETRACK_COMPL
# 0                 NaN              NaN                  NaN
# 1                 NaN              NaN                  NaN
# 2                 NaN              NaN                  NaN
# 3                 NaN              NaN                  NaN
# 4                 NaN              NaN                  NaN
#
# [5 rows x 801 columns]

# %%
# Load a single example graph & peek
g = nx.read_graphml(files[0])
print("loaded:", files[0].name)
print("nodes:", g.number_of_nodes(), "edges:", g.number_of_edges())

# peek a node
n0 = list(g.nodes())[0]
print("\nexample node:", n0)
print("node attrs:", g.nodes[n0])

# peek an edge
e0 = list(g.edges())[0]
print("\nexample edge:", e0)
print("edge attrs:", g.edges[e0])
# Out:
# loaded: 100206_repeated10_scale33.graphml
# nodes: 83 edges: 725
#
# example node: 1
# node attrs: {'dn_position_x': 34.0889628925, 'dn_position_y': 83.5585156993, 'dn_position_z': 8.72454804948, 'dn_correspondence_id': '1', 'dn_region': 'cortical', 'dn_fsname': 'lateralorbitofrontal', 'dn_name': 'rh.lateralorbitofrontal', 'dn_hemisphere': 'right'}
#
# example edge: ('1', '34')
# edge attrs: {'fiber_length_mean': 13.3253736496, 'FA_mean': 0.202591825277, 'number_of_fibers': 10.125}

# %% [markdown]
# ## Following cell creates a smaller version of subjects csv file with just age and id

# %%
# keep only subject ID and age
meta = pheno[['Subject', 'Age_in_Yrs']].copy()

# rename columns
meta = meta.rename(columns={
    'Subject': 'subject_id',
    'Age_in_Yrs': 'age'
})

meta['subject_id'] = meta['subject_id'].astype(str)  # raw data uses integers for id

meta.to_csv("data/HCP/HCP_subjects_age_only.csv", index=False)
meta.shape
# Out:
# (1206, 2)

# %%
def graph_to_data(graph_path):
    G = nx.read_graphml(graph_path)
    nodes = list(G.nodes())
    idx = {n: i for i, n in enumerate(nodes)}

    src, dst = [], []
    for u, v in G.edges():
        ui, vi = idx[u], idx[v]
        src += [ui, vi]
        dst += [vi, ui]
    edge_index = torch.tensor([src, dst], dtype=torch.long)

    coords = np.zeros((len(nodes), 3))
    for n in nodes:
        attrs = g.nodes[n]
        coords[idx[n]] = [float(attrs['dn_position_x']), float(attrs['dn_position_y']), float(attrs['dn_position_z'])]

    x = torch.tensor(coords, dtype=torch.float32)

    # Label (age)
    filename = graph_path.name
    subject_id = filename.split('_')[0]
    age = meta.loc[meta.subject_id == subject_id, "age"].values[0]
    y = torch.tensor([age], dtype=torch.float32)

    return Data(x=x, edge_index=edge_index, y=y)

# %%
# Use a small subset first to test
N = 200
subset_files = files[:N]

data_list = [graph_to_data(p) for p in subset_files]
len(data_list)
# Out:
# 200

# %%
from sklearn.model_selection import train_test_split

train_idx, test_idx = train_test_split(range(len(data_list)), test_size=0.2, random_state=42)
train_idx, val_idx = train_test_split(train_idx, test_size=0.2, random_state=42)

train_data = [data_list[i] for i in train_idx]
val_data   = [data_list[i] for i in val_idx]
test_data  = [data_list[i] for i in test_idx]

# %%
import torch.nn as nn
from torch_geometric.nn import SAGEConv

# %%
class GraphSAGERegressor(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1 = SAGEConv(1, 16)
        self.conv2 = SAGEConv(16, 16)
        self.readout = nn.Linear(16, 1)

    def forward(self, data):
        x, edge_index = data.x, data.edge_index
        x = torch.relu(self.conv1(x, edge_index))
        x = torch.relu(self.conv2(x, edge_index))
        x = x.mean(dim=0)  # graph level mean pooling
        return self.readout(x)

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = GraphSAGERegressor().to(device)
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)
loss_fn = nn.L1Loss()

def run_batch(data_list, train=True):
    total_loss = 0
    for data in data_list:
        data = data.to(device)
        pred = model(data)
        loss = loss_fn(pred, data.y)
        if train:
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
        total_loss += loss.item()
    return total_loss / len(data_list)

for epoch in range(1, 31):
    train_loss = run_batch(train_data, train=True)
    val_loss = run_batch(val_data, train=False)
    if epoch % 5 == 0:
        print(f"epoch {epoch:3d} | train MAE {train_loss:.3f} | val MAE {val_loss:.3f}")
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[40], line 20
#      17     return total_loss / len(data_list)
#      19 for epoch in range(1, 31):
# ---> 20     train_loss = run_batch(train_data, train=True)
#      21     val_loss = run_batch(val_data, train=False)
#      22     if epoch % 5 == 0:
#
# Cell In[40], line 10, in run_batch(data_list, train)
#       8 for data in data_list:
#       9     data = data.to(device)
# ---> 10     pred = model(data)
#      11     loss = loss_fn(pred, data.y)
#      12     if train:
#
# File ~/miniconda3/envs/cs224w-brain-graphs/lib/python3.12/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/cs224w-brain-graphs/lib/python3.12/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# Cell In[39], line 10, in GraphSAGERegressor.forward(self, data)
#       8 def forward(self, data):
#       9     x, edge_index = data.x, data.edge_index
# ---> 10     x = torch.relu(self.conv1(x, edge_index))
#      11     x = torch.relu(self.conv2(x, edge_index))
#      12     x = x.mean(dim=0)  # graph level mean pooling
#
# File ~/miniconda3/envs/cs224w-brain-graphs/lib/python3.12/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/cs224w-brain-graphs/lib/python3.12/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/cs224w-brain-graphs/lib/python3.12/site-packages/torch_geometric/nn/conv/sage_conv.py:135, in SAGEConv.forward(self, x, edge_index, size)
#     133 # propagate_type: (x: OptPairTensor)
#     134 out = self.propagate(edge_index, x=x, size=size)
# --> 135 out = self.lin_l(out)
#     137 x_r = x[1]
#     138 if self.root_weight and x_r is not None:
#
# File ~/miniconda3/envs/cs224w-brain-graphs/lib/python3.12/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/cs224w-brain-graphs/lib/python3.12/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/cs224w-brain-graphs/lib/python3.12/site-packages/torch_geometric/nn/dense/linear.py:127, in Linear.forward(self, x)
#     121 def forward(self, x: Tensor) -> Tensor:
#     122     r"""Forward pass.
#     123
#     124     Args:
#     125         x (torch.Tensor): The input features.
#     126     """
# --> 127     return F.linear(x, self.weight, self.bias)
#
# RuntimeError: mat1 and mat2 shapes cannot be multiplied (83x3 and 1x16)

# %%
test_mae = run_batch(test_data, train=False)
print(f"Test MAE: {test_mae:.3f} years")
# Out:
# Test MAE: 3.084 years
